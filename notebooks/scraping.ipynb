# %%
from google_play_scraper import reviews, Sort
import pandas as pd
import os

# %%
APPS = {
    "Commercial Bank of Ethiopia": "com.combanketh.mobilebanking",
    "Bank of Abyssinia": "com.boa.boaMobileBanking",
    "Dashen Bank": "com.dashen.amoleplus"
}

# %%
all_reviews = []

for bank_name, app_id in APPS.items():
    print(f"Scraping {bank_name}...")
    result, _ = reviews(
        app_id,
        lang='en',
        country='et',
        sort=Sort.NEWEST,
        count=500
    )
    df = pd.DataFrame(result)
    df['bank'] = bank_name
    df['source'] = 'Google Play'
    print(f"Got {len(df)} reviews for {bank_name}")
    all_reviews.append(df)
# Out:
# Scraping Commercial Bank of Ethiopia...
# Got 500 reviews for Commercial Bank of Ethiopia
# Scraping Bank of Abyssinia...
# Got 500 reviews for Bank of Abyssinia
# Scraping Dashen Bank...
# Got 0 reviews for Dashen Bank

# %%
combined = pd.concat(all_reviews, ignore_index=True)
combined = combined[['reviewId','content','score','at','bank','source']]
combined.columns = ['id','review','rating','date','bank','source']
combined.drop_duplicates(subset='id', inplace=True)
combined.dropna(subset=['review','rating'], inplace=True)
combined['date'] = pd.to_datetime(combined['date']).dt.strftime('%Y-%m-%d')
os.makedirs('data/raw', exist_ok=True)
combined.to_csv('data/raw/reviews.csv', index=False)
print(f"Total reviews: {len(combined)}")
combined.head()
# Out:
# Total reviews: 1000
#                                      id  \
# 0  f5202b8d-cbed-4441-8c24-64d67859f06d
# 1  01e4b090-3bb0-4252-8901-a5d4faf63ced
# 2  2caf219d-1b95-49a2-b092-bc8f12e6bd8c
# 3  d3cbb984-05a4-464e-a69f-3afa37873f0d
# 4  340b454f-c54a-43b5-8a0f-87fb2639f6c1
#
#                                               review  rating        date  \
# 0                                              trash     1.0  2026-05-19
# 1                                           poor app     1.0  2026-05-19
# 2                                               Nice     5.0  2026-05-19
# 3                                            nice vv     5.0  2026-05-19
# 4  እጅግ በጣም አሪፍ አፕ ነው። ነገር ግን የስልክ ቀፎ በቀየርኩ ቁጥር አን...     5.0  2026-05-19
#
#                           bank       source
# 0  Commercial Bank of Ethiopia  Google Play
# 1  Commercial Bank of Ethiopia  Google Play
# 2  Commercial Bank of Ethiopia  Google Play
# 3  Commercial Bank of Ethiopia  Google Play
# 4  Commercial Bank of Ethiopia  Google Play
